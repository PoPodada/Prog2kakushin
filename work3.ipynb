# %% [markdown]
# <a href="https://colab.research.google.com/github/PoPodada/Prog2kakushin/blob/main/work3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 画像検出の際に用いられるエッジ検出を行うプログラムです
# 物体の輪郭や特徴抽出、画像の領域分割等の画像解析に使われます

# %%
# !wget "https://drive.google.com/uc?export=download&id=1eAp0ppn0zwO2dF0W0jEvVUNi6hK--Int" -O dog.jpg
https://drive.google.com/file/d/1eAp0ppn0zwO2dF0W0jEvVUNi6hK--Int/view?usp=share_link

# %%
from google.colab import files
from google.colab.patches import cv2_imshow
import cv2


image = cv2.imread("dog.jpg")#エッジ処理したい画像を入力してください

gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)#グレースケール処理
edges = cv2.Canny(gray_image, 100, 200)
cv2_imshow(image)#画像を出力する
cv2_imshow(edges)#エッジ処理した画像を出力する
# Out:
# <PIL.Image.Image image mode=RGB size=320x214 at 0x7FB3445B8B20>
# <PIL.Image.Image image mode=L size=320x214 at 0x7FB3505E5AC0>

# %%
import numpy as np
image=cv2.imread("dog.jpg")#画像をイメージに入れる

text="sample"#出力される文字列
font=cv2.FONT_HERSHEY_SIMPLEX#フォント
color=(255,255,255)#色
thickness=2#文字の太さ

text_size=cv2.getTextSize(text,font,1,thickness)[0]
text_x=(image.shape[1]-text_size[0])//2
text_y=(image.shape[0]+text_size[1])//2

alpha=0.5
text_image=np.zeros(image.shape,np.uint8)
cv2.putText(text_image,text,(text_x,text_y),font,1,color,thickness)
cv2.addWeighted(text_image,alpha,image,1-alpha,0,image)
cv2_imshow(image)#画像を出力
# Out:
# <PIL.Image.Image image mode=RGB size=320x214 at 0x7FB3429C9E20>
